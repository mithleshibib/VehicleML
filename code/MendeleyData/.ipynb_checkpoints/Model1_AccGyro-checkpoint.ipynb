# %%
import turicreate as tc
import os

# %%
data=tc.SFrame.read_csv("sensor_raw.csv")
# Out:
# Finished parsing file /home/ubuntu/VehicleML/code/MendeleyData/sensor_raw.csv
# Parsing completed. Parsed 100 lines in 0.037873 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,float,float,float,float,float,float]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/ubuntu/VehicleML/code/MendeleyData/sensor_raw.csv
# Parsing completed. Parsed 1114 lines in 0.037211 secs.

# %%
data
# Out:
# Columns:
# 	Target(Class)	int
# 	GyroX	float
# 	GyroY	float
# 	GyroZ	float
# 	AccX	float
# 	AccY	float
# 	AccZ	float
#
# Rows: 1114
#
# Data:
# +---------------+----------------------+--------------------+
# | Target(Class) |        GyroX         |       GyroY        |
# +---------------+----------------------+--------------------+
# |       1       | -0.9236641221374046  | 3.6946564885496183 |
# |       1       | -0.9083969465648856  | 4.534351145038168  |
# |       1       |  0.7862595419847328  | 3.969465648854962  |
# |       1       |  0.3358778625954199  | 4.564885496183206  |
# |       1       |  3.3511450381679393  | 2.6946564885496183 |
# |       1       | -1.5038167938931295  | 3.183206106870229  |
# |       1       |  1.3587786259541987  | 8.725190839694656  |
# |       1       |  -1.083969465648855  | 4.106870229007634  |
# |       1       | 0.053435114503816786 | 5.083969465648855  |
# |       1       |  -1.106870229007634  | 3.656488549618321  |
# +---------------+----------------------+--------------------+
# +---------------------+----------------+-----------------+-----------------+
# |        GyroZ        |      AccX      |       AccY      |       AccZ      |
# +---------------------+----------------+-----------------+-----------------+
# |  0.8244274809160306 | 0.16259765625  | -0.086669921875 | -0.969482421875 |
# |  0.8320610687022901 |   0.17578125   |  -0.1005859375  |  -1.01318359375 |
# |  0.5877862595419847 | 0.32275390625  | -0.140380859375 |  -0.91162109375 |
# | -0.2519083969465649 | 0.480224609375 | -0.226806640625 | -0.936767578125 |
# | -0.1068702290076336 | 0.426025390625 |   -0.25390625   |  -0.9501953125  |
# |  -1.656488549618321 |  0.3837890625  |  -0.1416015625  | -0.919677734375 |
# | -0.9465648854961832 | 0.40478515625  |  -0.25732421875 | -0.862548828125 |
# | -0.6259541984732825 | 0.346923828125 | -0.106201171875 | -0.969970703125 |
# |  -2.221374045801527 | 0.276611328125 | -0.257568359375 |  -1.00830078125 |
# |  0.7786259541984732 | 0.158935546875 | -0.111572265625 | -0.971435546875 |
# +---------------------+----------------+-----------------+-----------------+
# [1114 rows x 7 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
data.show()
# Out:
# Materializing SFrame
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="2400" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"metadata\": {\"bubbleOpts\": {\"showAllFields\": false, \"fields\": [{\"field\": \"left\"}, {\"field\": \"right\"}, {\"field\": \"count\"}, {\"field\": \"label\"}]}}, \"width\": 800, \"height\": 2180, \"padding\": 8, \"data\": [{\"name\": \"pts_store\"}, {\"name\": \"source_2\", \"values\": [{\"a\": 0, \"title\": \"Target(Class)\", \"num_row\": 1114, \"type\": \"integer\", \"num_unique\": 4, \"num_missing\": 0, \"mean\": 2.490126, \"min\": 1.0, \"max\": 4.0, \"median\": 3.0, \"stdev\": 1.050943, \"numeric\": [{\"left\": -7, \"right\": -6, \"count\": 0}, {\"left\": -6, \"right\": -5, \"count\": 0}, {\"left\": -5, \"right\": -4, \"count\": 0}, {\"left\": -4, \"right\": -3, \"count\": 0}, {\"left\": -3, \"right\": -2, \"count\": 0}, {\"left\": -2, \"right\": -1, \"count\": 0}, {\"left\": -1, \"right\": 0, \"count\": 0}, {\"left\": 0, \"right\": 1, \"count\": 0}, {\"left\": 1, \"right\": 2, \"count\": 252}, {\"left\": 2, \"right\": 3, \"count\": 288}, {\"left\": 3, \"right\": 4, \"count\": 350}, {\"left\": 4, \"right\": 5, \"count\": 224}, {\"left\": 5, \"right\": 6, \"count\": 0}, {\"left\": 6, \"right\": 7, \"count\": 0}, {\"left\": 7, \"right\": 8, \"count\": 0}, {\"left\": 8, \"right\": 9, \"count\": 0}, {\"left\": 9, \"right\": 10, \"count\": 0}, {\"left\": 10, \"right\": 11, \"count\": 0}, {\"left\": 11, \"right\": 12, \"count\": 0}, {\"left\": 12, \"right\": 13, \"count\": 0}, {\"start\": -7, \"stop\": 13, \"step\": 1}], \"categorical\": []}, {\"a\": 1, \"title\": \"GyroX\", \"num_row\": 1114, \"type\": \"float\", \"num_unique\": 762, \"num_missing\": 0, \"mean\": -0.829957, \"min\": -14.946565, \"max\": 12.778626, \"median\": -0.694656, \"stdev\": 3.402768, \"numeric\": [{\"left\": -15.1426, \"right\": -13.7356, \"count\": 4}, {\"left\": -13.7356, \"right\": -12.3285, \"count\": 3}, {\"left\": -12.3285, \"right\": -10.9215, \"count\": 8}, {\"left\": -10.9215, \"right\": -9.5145, \"count\": 6}, {\"left\": -9.5145, \"right\": -8.10748, \"count\": 13}, {\"left\": -8.10748, \"right\": -6.70046, \"count\": 21}, {\"left\": -6.70046, \"right ...

# %%
data=data.shuffle()
data_train,data_test=tc.SFrame.random_split(data,0.7)
data_test1, data_validation=tc.SFrame.random_split(data_test,0.5)

# %%
model=tc.classifier.create(data,target='Target(Class)',validation_set=data_test1)
# Out:
# PROGRESS: The following methods are available for this type of problem.
# PROGRESS: BoostedTreesClassifier, RandomForestClassifier, DecisionTreeClassifier, LogisticClassifier
# PROGRESS: The returned model will be chosen according to validation accuracy.
# Boosted trees classifier:
# --------------------------------------------------------
# Number of examples          : 1114
# Number of classes           : 4
# Number of feature columns   : 6
# Number of unpacked features : 6
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# | Iteration | Elapsed Time | Training Accuracy | Validation Accuracy | Training Log Loss | Validation Log Loss |
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# | 1         | 0.007447     | 0.763016          | 0.693548            | 1.115052          | 1.143342            |
# | 2         | 0.024209     | 0.776481          | 0.715054            | 0.949235          | 0.996503            |
# | 3         | 0.040430     | 0.791741          | 0.731183            | 0.837453          | 0.891209            |
# | 4         | 0.057118     | 0.810592          | 0.758065            | 0.755697          | 0.817740            |
# | 5         | 0.072491     | 0.814183          | 0.741935            | 0.688283          | 0.750933            |
# | 10        | 0.144814     | 0.866248          | 0.811828            | 0.486890          | 0.555203            |
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# Random forest classifier:
# --------------------------------------------------------
# Number of examples          : 1114
# Number of classes           : 4
# Number of feature columns   : 6
# Number of unpacked features : 6
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# | Iteration | Elapsed Time | Training Accuracy | Validation Accuracy | Training Log Loss | Validation Log Loss |
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# | 1         | 0.014529     | 0.723519          | 0.715054            | 0.801250          | 0.849103            |
# | 2         | 0.025907     | 0.748654          | 0.747312            | 0.800013          | 0.849207            |
# | 3         | 0.040264     | 0.770198          | 0.747312            | 0.802759          | 0.856487            |
# | 4         | 0.054708     | 0.768402          | 0.725806            | 0.799692          | 0.847574            |
# | 5         | 0.078768     | 0.771095          | 0.709677            | 0.793092          | 0.843145            |
# | 10        | 0.142119     | 0.782765          | 0.736559            | 0.799614          | 0.847174            |
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# Decision tree classifier:
# --------------------------------------------------------
# Number of examples          : 1114
# Number of classes           : 4
# Number of feature columns   : 6
# Number of unpacked features : 6
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# | Iteration | Elapsed Time | Training Accuracy | Validation Accuracy | Training Log Loss | Validation Log Loss |
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# | 1         | 0.019415     | 0.763016          | 0.693548            | 0.733968          | 0.807703            |
# +-----------+--------------+-------------------+---------------------+-------------------+---------------------+
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 1114
# Number of classes           : 4
# Number of feature columns   : 6
# Number of unpacked features : 6
# Number of coefficients      : 21
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+-------------------+---------------------+
# | Iteration | Passes   | Elapsed Time | Training Accuracy | Validation Accuracy |
# +-----------+----------+--------------+-------------------+---------------------+
# | 1         | 2        | 0.015531     | 0.438959          | 0.430108            |
# | 2         | 3        | 0.020848     | 0.458707          | 0.462366            |
# | 3         | 4        | 0.026201     | 0.463196          | 0.473118            |
# | 4         | 5        | 0.029243     | 0.460503          | 0.467742            |
# | 5         | 6        | 0.032324     | 0.461400          | 0.467742            |
# +-----------+----------+--------------+-------------------+---------------------+
# SUCCESS: Optimal solution found.
# <pre></pre>
# PROGRESS: Model selection based on validation accuracy:
# PROGRESS: ---------------------------------------------
# PROGRESS: BoostedTreesClassifier          : 0.8118279569892473
# PROGRESS: RandomForestClassifier          : 0.7365591397849462
# PROGRESS: DecisionTreeClassifier          : 0.6935483870967742
# PROGRESS: LogisticClassifier              : 0.46774193548387094
# PROGRESS: ---------------------------------------------
# PROGRESS: Selecting BoostedTreesClassifier based on validation set performance.

# %%
result=model.predict(data_validation)
right=0
wrong=0
for i in range(len(result)):
    if result[i]==data_validation['Target(Class)'][i]:
        right+=1
    else:
        wrong+=1
print("Right=",right)
print("Wrong=",wrong)
# Out:
# Right= 119
# Wrong= 23

# %%
#model.save("Model1_sensor_raw")

# %%
path="/home/ubuntu/VehicleML/code/MendeleyData/Features By Window Size/"
filename=os.listdir(path)
for i in (filename):
    data=tc.SFrame.read_csv(path+i,verbose=False)
    data=data.shuffle()
    data_train,data_test=tc.SFrame.random_split(data,0.7)
    data_test1, data_validation=tc.SFrame.random_split(data_test,0.5)
    model=tc.classifier.create(data,target='Target',validation_set=data_test1,verbose=False)
    model.save("Features By Window Size Model/Model1_"+i)
    with open("ModelDetails.txt","a") as file:
        file.write("\n\n")
        file.write("#####################################################\n\n")
        file.write(i+"\n\n")
        file.write(model.summary(output="str"))

# %%
tc.visualization.columnwise_summary(data)
# Out:
# Materializing SFrame
# Warning: Skipping column 'GyroMaxY' [float]. Unable to show more than 50 columns.
# Further warnings of more than 50 columns will be suppressed.
# <html>                 <body>                     <iframe style="border:0;margin:0" width="1000" height="18300" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 padding:5px;                                 background:#AAAAAA;                                 border-radius:4px;                                 padding-left:10px;                                 padding-right:10px;                                 margin-right:5px;                             }                             .vega-actions{                                 margin-top:20px;                                 text-align:center                             }                            .vega-actions > a{                                 background:#999999;                            }                             </style>                         </head>                         <body>                             <div id="vis">                             </div>                             <script>                                 var vega_json = "{\"$schema\": \"https://vega.github.io/schema/vega/v4.json\", \"metadata\": {\"bubbleOpts\": {\"showAllFields\": false, \"fields\": [{\"field\": \"left\"}, {\"field\": \"right\"}, {\"field\": \"count\"}, {\"field\": \"label\"}]}}, \"width\": 800, \"height\": 18080, \"padding\": 8, \"data\": [{\"name\": \"pts_store\"}, {\"name\": \"source_2\", \"values\": [{\"a\": 0, \"title\": \"Target\", \"num_row\": 1102, \"type\": \"integer\", \"num_unique\": 4, \"num_missing\": 0, \"mean\": 2.490018, \"min\": 1.0, \"max\": 4.0, \"median\": 3.0, \"stdev\": 1.050188, \"numeric\": [{\"left\": -7, \"right\": -6, \"count\": 0}, {\"left\": -6, \"right\": -5, \"count\": 0}, {\"left\": -5, \"right\": -4, \"count\": 0}, {\"left\": -4, \"right\": -3, \"count\": 0}, {\"left\": -3, \"right\": -2, \"count\": 0}, {\"left\": -2, \"right\": -1, \"count\": 0}, {\"left\": -1, \"right\": 0, \"count\": 0}, {\"left\": 0, \"right\": 1, \"count\": 0}, {\"left\": 1, \"right\": 2, \"count\": 249}, {\"left\": 2, \"right\": 3, \"count\": 285}, {\"left\": 3, \"right\": 4, \"count\": 347}, {\"left\": 4, \"right\": 5, \"count\": 221}, {\"left\": 5, \"right\": 6, \"count\": 0}, {\"left\": 6, \"right\": 7, \"count\": 0}, {\"left\": 7, \"right\": 8, \"count\": 0}, {\"left\": 8, \"right\": 9, \"count\": 0}, {\"left\": 9, \"right\": 10, \"count\": 0}, {\"left\": 10, \"right\": 11, \"count\": 0}, {\"left\": 11, \"right\": 12, \"count\": 0}, {\"left\": 12, \"right\": 13, \"count\": 0}, {\"start\": -7, \"stop\": 13, \"step\": 1}], \"categorical\": []}, {\"a\": 1, \"title\": \"AccMeanX\", \"num_row\": 1102, \"type\": \"float\", \"num_unique\": 1065, \"num_missing\": 0, \"mean\": 0.250681, \"min\": 0.019642, \"max\": 0.445452, \"median\": 0.254778, \"stdev\": 0.080147, \"numeric\": [{\"left\": 0.0183165, \"right\": 0.0397643, \"count\": 22}, {\"left\": 0.0397643, \"right\": 0.0612121, \"count\": 15}, {\"left\": 0.0612121, \"right\": 0.0826599, \"count\": 7}, {\"left\": 0.0826599, \"right\": 0.104108, \"count\": 9}, {\"left\": 0.104108, \"right\": 0.125556, \"count\": 10}, {\"left\": 0.125556, \"right\": 0.147003, \"count\": 28}, {\"left\": 0.147003, \" ...
